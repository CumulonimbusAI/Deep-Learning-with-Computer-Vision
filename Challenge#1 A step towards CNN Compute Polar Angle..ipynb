# %%
# Polar co-ordinates of points are determined ..

import numpy as np

#represent points in the np.array for computation of their polar angles.
point = np.array([[0,0],[7,0.5],[3,1],[5,2],[3,3],[1,4],[5,5],[9,6]])
print(point)
# Out:
# [[0.  0. ]
#  [7.  0.5]
#  [3.  1. ]
#  [5.  2. ]
#  [3.  3. ]
#  [1.  4. ]
#  [5.  5. ]
#  [9.  6. ]]

# %%
#extract 'x' and 'y' co-ordinates from the np.array
x,y = point[:,0], point[:,1]
print(x,y) # print the x , y
# Out:
# [0. 7. 3. 5. 3. 1. 5. 9.] [0.  0.5 1.  2.  3.  4.  5.  6. ]

# %%
#compute the polar angle for the co-ordinates.
radius = np.sqrt(x**2+y**2)
theta = np.arctan2(y,x)
print(radius) #print the radius.
print(theta)  #print the polar angle.
# Out:
# [ 0.          7.01783442  3.16227766  5.38516481  4.24264069  4.12310563
#   7.07106781 10.81665383]
# [0.         0.07130746 0.32175055 0.38050638 0.78539816 1.32581766
#  0.78539816 0.5880026 ]

# %%
theta.sort() #sort polar angles.

# %%
print(theta) #now, print the sorted polar angles.
# Out:
# [0.         0.07130746 0.32175055 0.38050638 0.5880026  0.78539816
#  0.78539816 1.32581766]

# %% [markdown]
# [SCRIPT] : # ref: https://mathinsight.org/polar_coordinates
#
# In two dimensions, the Cartesian coordinates (x,y) specify the location of a point P in the plane. Another two-dimensional coordinate system is polar coordinates. Instead of using the signed distances along the two coordinate axes, polar coordinates specifies the location of a point P in the plane by its distance r from the origin and the angle θ made between the line segment from the origin to P and the positive x-axis. The polar coordinates (r,θ) of a point P are illustrated in the figure.
#
# ![polar.png](attachment:polar.png)
#
# As r ranges from 0 to infinity and θ ranges from 0 to 2π, the point P specified by the polar coordinates (r,θ) covers every point in the plane. Adding 2π to θ brings us back to the same point, so if we allowed θ to range over an interval larger than 2π, each point would have multiple polar coordinates. Hence, we typically restrict θ to be in the interal 0≤θ<2π. However, even with that restriction, there still is some non-uniqueness of polar coordinates: when r=0, the point P is at the origin independent of the value of θ.
#
# The pictures shown here represent polar coordinates r and θ for different points.
# ![0.32rad.png](attachment:0.32rad.png)
#
# This figure that corresponds to θ=0.32 radians maps to points with x,y at 3,1
# The next one corresponds to θ=0.79 radians and maps to points with x,y at 3,3 and the
# last one corresponds to θ=0.59 at point x,y at 9,6.
#
#
# ![0.79rad.png](attachment:0.79rad.png)
# ![0.58rad.png](attachment:0.58rad.png)
#
# Lets now discuss conversion forumale. We can calculate the Cartesian coordinates of a point with polar coordinates (r,θ) by forming the right triangle illustrated in the figure.
#
# ![polar.png](attachment:polar.png)
#
# The hypotenuse is the line segment from the origin to the point, and its length is r. The projection of this line segment on the x-axis is the leg of the triangle adjacent to the angle θ, so x=rcosθ. The y-component is determined by the other leg, so y=rsinθ.
# Our conversion formula is as shown here.
#
# ![polar-convertion-formulae.png](attachment:polar-convertion-formulae.png)
#
# Now, lets dive into our python implementation. We define numpy array for linear algebra representations of x,y co-ordinates. The co-ordinates are representated by point np.array at ine#7 and then print out for verification.
#
# In the 2nd code block , points are extracted from point np.array as x and y co-ordinates and printed. In the final block the polar angle and radius are computed using the conversion formulae and printed out.
